# %% [markdown]
# ## Load Model

# %%
import pandas as pd
import numpy as np

# %%
import pickle

# %%
model_loaded = pickle.load(open('model_final.sav', 'rb'))

model_loaded
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('binary', BinaryEncoder(),
#                                                   ['Type', 'Region', 'Make']),
#                                                  ('onehot',
#                                                   OneHotEncoder(drop='first'),
# ...

# %% [markdown]
# Membuat data dummy dengan chatgpt

# %%
# Menentukan jumlah data dummy yang ingin dibuat
n = 10

# Membuat data dummy
data = {
    'Type': ['Corolla', 'Civic', 'Focus', '320i', 'A4', 'Altima', 'Malibu', 'Civic', 'Altima', 'Corolla'],
    'Region': ['Riyadh', 'Jeddah', 'Dammam', 'Abha', 'Makkah', 'Khobar', 'Taef', 'Qassim', 'Hail', 'Jazan'],
    'Make': ['Toyota', 'Honda', 'Ford', 'BMW', 'Audi', 'Nissan', 'Chevrolet', 'Honda', 'Nissan', 'Toyota'],
    'Gear_Type': ['Automatic', 'Manual', 'Automatic', 'Automatic', 'Manual', 'Automatic', 'Automatic', 'Manual', 'Automatic', 'Manual'],
    'Origin': ['Saudi', 'Gulf Arabic', 'Other', 'Saudi', 'Unknown', 'Gulf Arabic', 'Saudi', 'Other', 'Saudi', 'Unknown'],
    'Options': ['Full', 'Semi Full', 'Standard', 'Full', 'Full', 'Standard', 'Semi Full', 'Full', 'Standard', 'Semi Full'],
    'Year': [2018, 2015, 2014, 2019, 2016, 2017, 2013, 2012, 2011, 2020],
    'Engine_Size': [1.6, 1.8, 2.0, 2.0, 1.4, 2.5, 2.4, 1.8, 2.5, 1.6],
    'Mileage': [60000, 80000, 120000, 40000, 90000, 70000, 110000, 130000, 150000, 30000],
    'Negotiable': [False] * 10
}

# Membuat DataFrame
df = pd.DataFrame(data)

# Menampilkan data
df.head()
# Out:
#       Type  Region    Make  Gear_Type       Origin    Options  Year  \
# 0  Corolla  Riyadh  Toyota  Automatic        Saudi       Full  2018
# 1    Civic  Jeddah   Honda     Manual  Gulf Arabic  Semi Full  2015
# 2    Focus  Dammam    Ford  Automatic        Other   Standard  2014
# 3     320i    Abha     BMW  Automatic        Saudi       Full  2019
# 4       A4  Makkah    Audi     Manual      Unknown       Full  2016
#
#    Engine_Size  Mileage  Negotiable
# 0          1.6    60000       False
# 1          1.8    80000       False
# 2          2.0   120000       False
# 3          2.0    40000       False
# 4          1.4    90000       False

# %%
X = df.drop(columns='Negotiable')

# %%
y_pred = model_loaded.predict(X)

# %%
y_pred
# Out:
# array([ 60991.77 ,  43098.734,  34246.18 , 176057.14 ,  80758.555,
#         66571.18 ,  25929.248,  31355.814,  14555.419,  44869.332],
#       dtype=float32)

# %%
df_prediksi = pd.DataFrame()
df_prediksi = X.copy()
df_prediksi['Predicted_Price'] = y_pred

# %%
df_prediksi
# Out:
#       Type  Region       Make  Gear_Type       Origin    Options  Year  \
# 0  Corolla  Riyadh     Toyota  Automatic        Saudi       Full  2018
# 1    Civic  Jeddah      Honda     Manual  Gulf Arabic  Semi Full  2015
# 2    Focus  Dammam       Ford  Automatic        Other   Standard  2014
# 3     320i    Abha        BMW  Automatic        Saudi       Full  2019
# 4       A4  Makkah       Audi     Manual      Unknown       Full  2016
# 5   Altima  Khobar     Nissan  Automatic  Gulf Arabic   Standard  2017
# 6   Malibu    Taef  Chevrolet  Automatic        Saudi  Semi Full  2013
# 7    Civic  Qassim      Honda     Manual        Other       Full  2012
# 8   Altima    Hail     Nissan  Automatic        Saudi   Standard  2011
# 9  Corolla   Jazan     Toyota     Manual      Unknown  Semi Full  2020
#
#    Engine_Size  Mileage  Predicted_Price
# 0          1.6    60000     60991.769531
# 1          1.8    80000     43098.734375
# 2          2.0   120000     34246.179688
# ...

# %%
df_prediksi.sort_values(by='Year')
# Out:
#       Type  Region       Make  Gear_Type       Origin    Options  Year  \
# 8   Altima    Hail     Nissan  Automatic        Saudi   Standard  2011
# 7    Civic  Qassim      Honda     Manual        Other       Full  2012
# 6   Malibu    Taef  Chevrolet  Automatic        Saudi  Semi Full  2013
# 2    Focus  Dammam       Ford  Automatic        Other   Standard  2014
# 1    Civic  Jeddah      Honda     Manual  Gulf Arabic  Semi Full  2015
# 4       A4  Makkah       Audi     Manual      Unknown       Full  2016
# 5   Altima  Khobar     Nissan  Automatic  Gulf Arabic   Standard  2017
# 0  Corolla  Riyadh     Toyota  Automatic        Saudi       Full  2018
# 3     320i    Abha        BMW  Automatic        Saudi       Full  2019
# 9  Corolla   Jazan     Toyota     Manual      Unknown  Semi Full  2020
#
#    Engine_Size  Mileage  Predicted_Price
# 8          2.5   150000     14555.418945
# 7          1.8   130000     31355.814453
# 6          2.4   110000     25929.248047
# ...

# %% [markdown]
# Insight:
# - Hasil prediksi menunjukkan bahwa ada kecenderungan kenaikkan harga ketika mobil dengan tahun yang tinggi, walaupun ada satu yang turun drastis yaitu tahun 2020, kemungkinan disebabkan oleh feature lain seperti Type, Option, Gear Type, dan lainnya.
# - Harga mobil tertinggi ada di mobil tahun 2019, BMW 320i.
